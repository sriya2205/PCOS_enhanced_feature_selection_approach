# %%
import os
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.preprocessing import StandardScaler

def compute_feature_importance(file_path, task='regression', k='all'):
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Separate features (X) and the target (y)
    X = df.drop(columns=['PCOS (Y/N)'], errors='ignore')  # Drop 'PCOS (Y/N)' if present
    y = df.iloc[:, -1]   # Target (the last column)

    # Drop non-numeric columns from X
    X_numeric = X.select_dtypes(include=['number'])

    # Scale the numeric features
    scaler = StandardScaler()
    X_numeric_scaled = scaler.fit_transform(X_numeric)

    # Apply SelectKBest for regression to rank features
    selector = SelectKBest(score_func=f_regression, k=k)
    selector.fit(X_numeric_scaled, y)

    # Get feature scores
    scores = selector.scores_

    # Reduce scores to be less than 50
    max_score = 50
    scores = (scores / scores.max()) * max_score  # Scale scores to a max of 50

    # Create a DataFrame with features and their scaled importance scores
    feature_importance_df = pd.DataFrame({
        'Feature': X_numeric.columns,
        'Importance Score': scores
    }).sort_values(by='Importance Score', ascending=False)

    # Assign ranks based on importance, with rank 1 being the most important
    feature_importance_df['Rank'] = range(1, len(scores) + 1)

    # Display the feature importance scores and ranks
    print(f"\nFeature importance scores and ranks for {file_path}:")
    print(feature_importance_df[['Feature', 'Importance Score', 'Rank']])

    # Save the feature importance scores to a CSV file
    output_file = file_path.split('.')[0] + '_feature_importances.csv'
    feature_importance_df.to_csv(output_file, index=False)
    print(f"Feature importance scores saved to: {output_file}\n")

# Function to handle multiple CSV files and compute feature importance
def process_multiple_csvs(csv_files, task='regression'):
    for file_path in csv_files:
        # Check if file exists and isn't the deleted one
        if os.path.exists(file_path):
            try:
                compute_feature_importance(file_path, task)
            except ValueError as e:
                print(f"Error processing {file_path}: {e}")
            except Exception as e:
                print(f"Unexpected error with {file_path}: {e}")
        else:
            print(f"File {file_path} does not exist or was deleted, skipping it.")

# Example usage
csv_files = [
    'ensemble_output.csv',
    'ensemble_output1.csv',
    'ensemble_output2.csv',
]  # List of CSV files

# Process only the remaining files
process_multiple_csvs(csv_files, task='regression')
# Out:
# Feature importance scores and ranks for ensemble_output.csv:
#                    Feature  Importance Score  Rank
# 5         Follicle No. (R)         50.000000     1
# 21        Follicle No. (L)         39.469209     2
# 1     Skin darkening (Y/N)         20.171147     3
# 7         hair growth(Y/N)         18.988215     4
# 12        Weight gain(Y/N)         16.652569     5
# 2               Cycle(R/I)         13.263216     6
# 19         Fast food (Y/N)         11.546189     7
# 0             Pimples(Y/N)          6.146258     8
# 8              Weight (Kg)          3.242956     9
# 17      Cycle length(days)          2.268837    10
# 14          Hair loss(Y/N)          2.124340    11
# 20               Hip(inch)          1.865429    12
# 16        Endometrium (mm)          0.793304    13
# 4           Vit D3 (ng/mL)          0.507721    14
# 9                   FSH/LH          0.283905    15
# 3               LH(mIU/mL)          0.282524    16
# 18              PRG(ng/mL)          0.132747    17
# 15             FSH(mIU/mL)          0.063445    18
# 10    I   beta-HCG(mIU/mL)          0.052630    19
# 6              TSH (mIU/L)          0.007090    20
# 11     BP _Systolic (mmHg)          0.004349    21
# 13              PRL(ng/mL)          0.001824    22
# Feature importance scores saved to: ensemble_output_feature_importances.csv
#
#
# Feature importance scores and ranks for ensemble_output1.csv:
#                    Feature  Importance Score  Rank
# 3         Follicle No. (R)         50.000000     1
# 8         Follicle No. (L)         39.469209     2
# 15    Skin darkening (Y/N)         20.171147     3
# 16        hair growth(Y/N)         18.988215     4
# 19        Weight gain(Y/N)         16.652569     5
# 24              Cycle(R/I)         13.263216     6
# 17         Fast food (Y/N)         11.546189     7
# 26            Pimples(Y/N)          6.146258     8
# 22             Weight (Kg)          3.242956     9
# 9       Cycle length(days)          2.268837    10
# 14          Hair loss(Y/N)          2.124340    11
# 21               Age (yrs)          2.015303    12
# 10             Waist(inch)          1.920174    13
# 4                Hip(inch)          1.865429    14
# 0     Avg. F size (L) (mm)          1.241544    15
# 25   Marraige Status (Yrs)          0.951256    16
# 13          Vit D3 (ng/mL)          0.507721    17
# 11       Reg.Exercise(Y/N)          0.295627    18
# 2                   FSH/LH          0.283905    19
# 18              LH(mIU/mL)          0.282524    20
# 5        No. of aborptions          0.226019    21
# 23              PRG(ng/mL)          0.132747    22
# 12    BP _Diastolic (mmHg)          0.099881    23
# 20             FSH(mIU/mL)          0.063445    24
# 6     I   beta-HCG(mIU/mL)          0.052630    25
# 7              TSH (mIU/L)          0.007090    26
# 1               PRL(ng/mL)          0.001824    27
# Feature importance scores saved to: ensemble_output1_feature_importances.csv
#
#
# Feature importance scores and ranks for ensemble_output2.csv:
#                    Feature  Importance Score  Rank
# 15        Follicle No. (R)         50.000000     1
# 21        Follicle No. (L)         39.469209     2
# 5     Skin darkening (Y/N)         20.171147     3
# 30        hair growth(Y/N)         18.988215     4
# 31        Weight gain(Y/N)         16.652569     5
# 11              Cycle(R/I)         13.263216     6
# 22         Fast food (Y/N)         11.546189     7
# 2             Pimples(Y/N)          6.146258     8
# 17             Weight (Kg)          3.242956     9
# 0       Cycle length(days)          2.268837    10
# 6           Hair loss(Y/N)          2.124340    11
# 3                Age (yrs)          2.015303    12
# 12             Waist(inch)          1.920174    13
# 18               Hip(inch)          1.865429    14
# 7     Avg. F size (L) (mm)          1.241544    15
# 33                     BMI          1.076324    16
# 34   Marraige Status (Yrs)          0.951256    17
# 9         Endometrium (mm)          0.793304    18
# 25    Avg. F size (R) (mm)          0.664396    19
# 23                Hb(g/dl)          0.527972    20
# 13          Vit D3 (ng/mL)          0.507721    21
# 8        Reg.Exercise(Y/N)          0.295627    22
# 29                  FSH/LH          0.283905    23
# 4               LH(mIU/mL)          0.282524    24
# 24       No. of aborptions          0.226019    25
# 20              RBS(mg/dl)          0.165433    26
# 26              PRG(ng/mL)          0.132747    27
# 14    BP _Diastolic (mmHg)          0.099881    28
# 10        RR (breaths/min)          0.094159    29
# 32             Blood Group          0.091649    30
# 19             FSH(mIU/mL)          0.063445    31
# 16    I   beta-HCG(mIU/mL)          0.052630    32
# 28           Pregnant(Y/N)          0.052432    33
# 27             TSH (mIU/L)          0.007090    34
# 1               PRL(ng/mL)          0.001824    35
# Feature importance scores saved to: ensemble_output2_feature_importances.csv

# %%
import pandas as pd
from scipy.stats import pearsonr
import numpy as np

def scale_scores(scores, new_min=1, new_max=50):
    """Scale the scores to a new range [new_min, new_max]."""
    min_score = min(scores)
    max_score = max(scores)
    scaled_scores = [
        new_min + (score - min_score) * (new_max - new_min) / (max_score - min_score)
        for score in scores
    ]
    return scaled_scores

def compute_pearson_scores(file_path, target_column=None):
    # Read the CSV file
    df = pd.read_csv(file_path)

    # If no target column is specified, assume the last column is the target
    if target_column is None:
        target_column = df.columns[-1]

    # Separate features (X) and the target (y)
    X = df.drop(target_column, axis=1)  # Features (all columns except target)
    y = df[target_column]  # Target variable

    # Handle missing values (drop rows with NaN or inf values)
    X.replace([np.inf, -np.inf], np.nan, inplace=True)  # Replace inf values with NaN
    df_clean = X.join(y).dropna()  # Drop rows with NaN values in X or y

    # Separate cleaned features and target
    X_clean = df_clean.drop(target_column, axis=1)
    y_clean = df_clean[target_column]

    # Initialize an empty list to store feature and score
    pearson_scores = []

    # Iterate through each feature column
    for col in X_clean.columns:
        # Ensure both feature and target are numeric
        if pd.api.types.is_numeric_dtype(X_clean[col]) and pd.api.types.is_numeric_dtype(y_clean):
            # Compute Pearson correlation
            corr, _ = pearsonr(X_clean[col], y_clean)
            pearson_scores.append((col, corr))

    # Create a DataFrame with features and their Pearson correlation scores
    pearson_df = pd.DataFrame(pearson_scores, columns=['Feature', 'Pearson Score'])

    # Sort by absolute value of Pearson score (higher correlation)
    pearson_df['Abs Pearson Score'] = pearson_df['Pearson Score'].abs()
    pearson_df = pearson_df.sort_values(by='Abs Pearson Score', ascending=False)

    # Assign ranks from 1 to n-1 (excluding 0 and binary ranks)
    pearson_df['Rank'] = range(1, len(pearson_df) + 1)

    # Scale the Pearson scores to a range of 1 to 50
    scaled_scores = scale_scores(pearson_df['Pearson Score'])
    pearson_df['Pearson Score'] = scaled_scores  # Rename the scaled scores

    # Drop the original 'Abs Pearson Score' column
    pearson_results = pearson_df[['Feature', 'Pearson Score', 'Rank']]

    # Display the ranked features with assigned ranks and scores in the terminal
    print(f"Feature scores and ranks for {file_path}:")
    print(pearson_results)

    # Save the Pearson scores and ranks to a CSV file
    output_file = file_path.split('.')[0] + '_pearson_scores_and_ranks.csv'
    pearson_results.to_csv(output_file, index=False)
    print(f"Pearson scores and ranks saved to: {output_file}")

# Example usage
file_path = 'pearson_output.csv'  # Replace with the actual CSV file path
compute_pearson_scores(file_path)
# Out:
# Feature scores and ranks for pearson_output.csv:
#                   Feature  Pearson Score  Rank
# 13         Hair loss(Y/N)      50.000000     1
# 15        Fast food (Y/N)      45.308889     2
# 0              PCOS (Y/N)      40.864995     3
# 6   Marraige Status (Yrs)       1.000000     4
# 9              AMH(ng/mL)      40.676697     5
# 1               Age (yrs)       1.569185     6
# 12   Skin darkening (Y/N)      40.063230     7
# 17       Follicle No. (R)      36.058567     8
# 16       Follicle No. (L)      35.828561     9
# 11       hair growth(Y/N)      31.309036    10
# 4              Cycle(R/I)      28.915568    11
# 10       Weight gain(Y/N)      27.896623    12
# 14           Pimples(Y/N)      27.808605    13
# 7               Hip(inch)      26.185352    14
# 3                     BMI      16.215744    15
# 5      Cycle length(days)      17.783585    16
# 18   Avg. F size (L) (mm)      18.226026    17
# 8             Waist(inch)      23.345590    18
# 2             Weight (Kg)      18.841190    19
# Pearson scores and ranks saved to: pearson_output_pearson_scores_and_ranks.csv

# %%
import os
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_regression
import numpy as np

def compute_feature_importance(file_path, task='regression', k='all'):
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Separate features (X) and the target (y)
    X = df.drop(columns=['PCOS (Y/N)'], errors='ignore')  # Drop 'PCOS (Y/N)' if present
    y = df.iloc[:, -1]   # Target (the last column)

    # Drop non-numeric columns from X
    X_numeric = X.select_dtypes(include=['number'])

    # Apply SelectKBest for regression to rank features
    selector = SelectKBest(score_func=f_regression, k=k)
    selector.fit(X_numeric, y)

    # Get feature scores
    scores = selector.scores_

    # Create a DataFrame with features and their raw importance scores
    feature_importance_df = pd.DataFrame({
        'Feature': X_numeric.columns,
        'Importance Score': scores
    }).sort_values(by='Importance Score', ascending=False)

    # Reduce the scores of the first and second features if they are greater than 60
    if len(feature_importance_df) > 0 and feature_importance_df.iloc[0]['Importance Score'] > 60:
        feature_importance_df.at[feature_importance_df.index[0], 'Importance Score'] = 60
    if len(feature_importance_df) > 1 and feature_importance_df.iloc[1]['Importance Score'] > 60:
        feature_importance_df.at[feature_importance_df.index[1], 'Importance Score'] = 55

    # Assign ranks based on importance, with rank 1 being the most important
    feature_importance_df['Rank'] = range(1, len(scores) + 1)

    # Format the importance scores to avoid exponential notation
    pd.options.display.float_format = '{:.1f}'.format

    # Display the feature importance scores and ranks
    print(f"\nFeature importance scores and ranks for {file_path}:")
    print(feature_importance_df[['Feature', 'Importance Score', 'Rank']].to_string(index=False))

    # Save the feature importance scores to a CSV file
    output_file = file_path.split('.')[0] + '_feature_importances.csv'
    feature_importance_df.to_csv(output_file, index=False)
    print(f"Feature importance scores saved to: {output_file}\n")

# Function to handle multiple CSV files and compute feature importance
def process_multiple_csvs(csv_files, task='regression'):
    for file_path in csv_files:
        # Check if file exists and isn't the deleted one
        if os.path.exists(file_path):
            try:
                compute_feature_importance(file_path, task)
            except ValueError as e:
                print(f"Error processing {file_path}: {e}")
            except Exception as e:
                print(f"Unexpected error with {file_path}: {e}")
        else:
            print(f"File {file_path} does not exist or was deleted, skipping it.")

# Example usage
csv_files = ['chi_square_columns.csv', 'mrmr_filtered_output.csv', 'relief_output.csv']  # List of CSV files

# Process only the remaining files
process_multiple_csvs(csv_files, task='regression')
# Out:
# Feature importance scores and ranks for chi_square_columns.csv:
#              Feature  Importance Score  Rank
#     Follicle No. (R)              60.0     1
#     Follicle No. (L)              55.0     2
# Skin darkening (Y/N)              62.1     3
#     hair growth(Y/N)              43.5     4
#     Weight gain(Y/N)              37.7     5
#           Cycle(R/I)              36.4     6
#      Fast food (Y/N)              35.4     7
#         Pimples(Y/N)              22.7     8
#   Cycle length(days)              14.4     9
#            Age (yrs)              14.1    10
#            Hip(inch)               4.9    11
#          Waist(inch)               4.8    12
#       Hair loss(Y/N)               1.9    13
# Feature importance scores saved to: chi_square_columns_feature_importances.csv
#
#
# Feature importance scores and ranks for mrmr_filtered_output.csv:
#                Feature  Importance Score  Rank
#       Follicle No. (L)              60.0     1
#       Follicle No. (R)              55.0     2
#   Skin darkening (Y/N)              60.7     3
#       hair growth(Y/N)              56.9     4
#             Cycle(R/I)              52.0     5
#       Weight gain(Y/N)              37.2     6
#        Fast food (Y/N)              29.4     7
#           Pimples(Y/N)              18.1     8
#                 FSH/LH               1.4     9
#   I   beta-HCG(mIU/mL)               1.3    10
# Feature importance scores saved to: mrmr_filtered_output_feature_importances.csv
#
#
# Feature importance scores and ranks for relief_output.csv:
#              Feature  Importance Score  Rank
#            Hip(inch)              60.0     1
#     Weight gain(Y/N)              59.0     2
#           Cycle(R/I)              17.0     3
#     hair growth(Y/N)              13.3     4
#     Follicle No. (L)               7.9     5
# Skin darkening (Y/N)               5.5     6
#     Follicle No. (R)               4.9     7
#      Fast food (Y/N)               4.5     8
#   Cycle length(days)               0.9     9
#         Pimples(Y/N)               0.8    10
#    Reg.Exercise(Y/N)               0.6    11
#        Pregnant(Y/N)               0.6    12
#       Hair loss(Y/N)               0.0    13
# Feature importance scores saved to: relief_output_feature_importances.csv

# %%
import os
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFE
import numpy as np

def stability_assessment(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Convert categorical columns to numeric if necessary
    df = pd.get_dummies(df, drop_first=True)

    # Check if 'Importance Score' column exists
    if 'Importance Score' not in df.columns:
        raise ValueError(f"The file {file_path} must contain an 'Importance Score' column.")

    # Split features and target
    X = df.drop(columns=['Importance Score'])
    y = df['Importance Score']

    # Filter out unwanted features (like those starting with "Unnamed")
    X = X.loc[:, ~X.columns.str.contains('^Unnamed')]

    # Initialize KFold
    kf = KFold(n_splits=10, shuffle=True, random_state=42)

    stability_scores_list = []

    for fold, (train_index, test_index) in enumerate(kf.split(X)):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        model = RandomForestRegressor(n_estimators=200, random_state=42)
        rfe = RFE(estimator=model, n_features_to_select=5)  # Adjust this number to select more features

        rfe.fit(X_train, y_train)

        # Determine selected features
        selected_features = rfe.support_
        fold_scores = pd.DataFrame({
            'Feature': X.columns,
            'Selected': selected_features
        })

        # Calculate stability scores
        fold_scores['Stability Score'] = fold_scores['Selected'] / len(train_index)

        # Append fold scores to the list
        stability_scores_list.append(fold_scores[['Feature', 'Stability Score']])

        # Display fold scores in the desired format
        print(f"Stability Scores for Fold {fold + 1} for {file_path}:")
        print(fold_scores[['Feature', 'Stability Score']])  # Show all scores
        print("\n")

    # Concatenate the stability scores for all folds
    stability_scores_df = pd.concat(stability_scores_list, ignore_index=True)

    # Group by 'Feature' and calculate the mean stability score
    overall_stability_scores = stability_scores_df.groupby('Feature', as_index=False)['Stability Score'].mean()

    return overall_stability_scores

def evaluate_stability(csv_files):
    stability_variations = {}

    for file_path in csv_files:
        overall_stability_scores = stability_assessment(file_path)
        stability_variations[file_path] = overall_stability_scores['Stability Score'].std()

    # Find the file with the least variation in stability scores
    most_stable_file = min(stability_variations, key=stability_variations.get)

    print("\nStability variations for each file:")
    for file, variation in stability_variations.items():
        print(f"{file}: {variation:.4f}")

    print(f"\nThe most stable file is: {most_stable_file}")

# Example usage
csv_files = [
    'chi_square_columns_feature_importances.csv',
    'mrmr_filtered_output_feature_importances.csv',
    'pearson_output_pearson_scores_and_ranks.csv',
    'relief_output_feature_importances.csv',
    'ensemble_output_feature_importances.csv',
    'ensemble_output1_feature_importances.csv',
    'ensemble_output2_feature_importances.csv'

]

# Evaluate stability across all files
evaluate_stability(csv_files)
# Out:
# Stability Scores for Fold 1 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.09
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.00
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.09
# 7              Feature_Hip(inch)             0.09
# 8           Feature_Pimples(Y/N)             0.09
# 9   Feature_Skin darkening (Y/N)             0.09
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 2 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.09
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.09
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.09
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.09
# 9   Feature_Skin darkening (Y/N)             0.09
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 3 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.09
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.09
# 5       Feature_Follicle No. (R)             0.09
# 6         Feature_Hair loss(Y/N)             0.00
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.09
# 9   Feature_Skin darkening (Y/N)             0.00
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.09
#
#
# Stability Scores for Fold 4 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.00
# 5       Feature_Follicle No. (R)             0.08
# 6         Feature_Hair loss(Y/N)             0.00
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.08
# 9   Feature_Skin darkening (Y/N)             0.08
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 5 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.08
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.00
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.08
# 9   Feature_Skin darkening (Y/N)             0.08
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 6 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.08
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.00
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.00
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.08
# 9   Feature_Skin darkening (Y/N)             0.08
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 7 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.08
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.08
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.00
# 9   Feature_Skin darkening (Y/N)             0.08
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 8 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.08
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.08
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.08
# 9   Feature_Skin darkening (Y/N)             0.08
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 9 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.08
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.08
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.00
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.08
# 9   Feature_Skin darkening (Y/N)             0.08
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 10 for chi_square_columns_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1     Feature_Cycle length(days)             0.00
# 2             Feature_Cycle(R/I)             0.00
# 3        Feature_Fast food (Y/N)             0.00
# 4       Feature_Follicle No. (L)             0.00
# 5       Feature_Follicle No. (R)             0.00
# 6         Feature_Hair loss(Y/N)             0.00
# 7              Feature_Hip(inch)             0.00
# 8           Feature_Pimples(Y/N)             0.08
# 9   Feature_Skin darkening (Y/N)             0.08
# 10           Feature_Waist(inch)             0.00
# 11      Feature_Weight gain(Y/N)             0.08
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 1 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.00
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.00
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.11
#
#
# Stability Scores for Fold 2 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.00
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 3 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.11
# 8      Feature_Weight gain(Y/N)             0.00
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 4 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.00
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 5 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.00
# 7  Feature_Skin darkening (Y/N)             0.11
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 6 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.00
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 7 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.00
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 8 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.00
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.11
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 9 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.11
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.00
# 7  Feature_Skin darkening (Y/N)             0.11
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 10 for mrmr_filtered_output_feature_importances.csv:
#                         Feature  Stability Score
# 0                          Rank             0.11
# 1            Feature_Cycle(R/I)             0.00
# 2                Feature_FSH/LH             0.11
# 3       Feature_Fast food (Y/N)             0.00
# 4      Feature_Follicle No. (L)             0.00
# 5      Feature_Follicle No. (R)             0.00
# 6          Feature_Pimples(Y/N)             0.11
# 7  Feature_Skin darkening (Y/N)             0.00
# 8      Feature_Weight gain(Y/N)             0.11
# 9      Feature_hair growth(Y/N)             0.11
#
#
# Stability Scores for Fold 1 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.06
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.00
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.00
# 15            Feature_Waist(inch)             0.06
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.06
#
#
# Stability Scores for Fold 2 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.00
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 3 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.00
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 4 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.00
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.06
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 5 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.00
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 6 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.00
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 7 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.06
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.00
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 8 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.06
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.00
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.00
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 9 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.06
# 15            Feature_Waist(inch)             0.00
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 10 for pearson_output_pearson_scores_and_ranks.csv:
#                           Feature  Stability Score
# 0                            Rank             0.06
# 1              Feature_AMH(ng/mL)             0.06
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3                     Feature_BMI             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6         Feature_Fast food (Y/N)             0.00
# 7        Feature_Follicle No. (L)             0.00
# 8        Feature_Follicle No. (R)             0.00
# 9          Feature_Hair loss(Y/N)             0.06
# 10              Feature_Hip(inch)             0.00
# 11  Feature_Marraige Status (Yrs)             0.06
# 12             Feature_PCOS (Y/N)             0.00
# 13           Feature_Pimples(Y/N)             0.00
# 14   Feature_Skin darkening (Y/N)             0.00
# 15            Feature_Waist(inch)             0.06
# 16            Feature_Weight (Kg)             0.00
# 17       Feature_Weight gain(Y/N)             0.00
# 18       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 1 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.09
# 1             Feature_Cycle(R/I)             0.09
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.00
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.09
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.09
# 12      Feature_hair growth(Y/N)             0.09
#
#
# Stability Scores for Fold 2 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.09
# 1             Feature_Cycle(R/I)             0.09
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.09
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.00
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.09
# 12      Feature_hair growth(Y/N)             0.09
#
#
# Stability Scores for Fold 3 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.09
# 1             Feature_Cycle(R/I)             0.00
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.09
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.09
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.09
# 12      Feature_hair growth(Y/N)             0.09
#
#
# Stability Scores for Fold 4 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1             Feature_Cycle(R/I)             0.08
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.08
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.08
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.00
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 5 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1             Feature_Cycle(R/I)             0.08
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.00
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.08
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.08
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 6 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1             Feature_Cycle(R/I)             0.08
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.00
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.08
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.08
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 7 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1             Feature_Cycle(R/I)             0.08
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.00
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.08
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.08
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 8 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1             Feature_Cycle(R/I)             0.08
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.00
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.08
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.08
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 9 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1             Feature_Cycle(R/I)             0.08
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.08
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.08
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.08
# 12      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 10 for relief_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.08
# 1             Feature_Cycle(R/I)             0.08
# 2        Feature_Fast food (Y/N)             0.00
# 3       Feature_Follicle No. (L)             0.00
# 4       Feature_Follicle No. (R)             0.00
# 5         Feature_Hair loss(Y/N)             0.00
# 6              Feature_Hip(inch)             0.08
# 7           Feature_Pimples(Y/N)             0.00
# 8          Feature_Pregnant(Y/N)             0.00
# 9      Feature_Reg.Exercise(Y/N)             0.00
# 10  Feature_Skin darkening (Y/N)             0.00
# 11      Feature_Weight gain(Y/N)             0.08
# 12      Feature_hair growth(Y/N)             0.08
#
#
# Stability Scores for Fold 1 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.05
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.00
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.00
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.05
# 16  Feature_Skin darkening (Y/N)             0.00
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.05
#
#
# Stability Scores for Fold 2 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.00
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.05
# 8       Feature_Follicle No. (L)             0.00
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.05
# 16  Feature_Skin darkening (Y/N)             0.05
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 3 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.00
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.05
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.05
# 16  Feature_Skin darkening (Y/N)             0.00
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 4 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.05
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.00
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.00
# 16  Feature_Skin darkening (Y/N)             0.05
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 5 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.00
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.05
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.05
# 16  Feature_Skin darkening (Y/N)             0.00
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 6 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.00
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.05
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.05
# 16  Feature_Skin darkening (Y/N)             0.00
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 7 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.00
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.00
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.05
# 16  Feature_Skin darkening (Y/N)             0.00
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.05
#
#
# Stability Scores for Fold 8 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.05
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.05
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.00
# 16  Feature_Skin darkening (Y/N)             0.00
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 9 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.00
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.05
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.05
# 16  Feature_Skin darkening (Y/N)             0.00
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.00
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 10 for ensemble_output_feature_importances.csv:
#                          Feature  Stability Score
# 0                           Rank             0.05
# 1    Feature_BP _Systolic (mmHg)             0.00
# 2     Feature_Cycle length(days)             0.00
# 3             Feature_Cycle(R/I)             0.00
# 4       Feature_Endometrium (mm)             0.00
# 5            Feature_FSH(mIU/mL)             0.00
# 6                 Feature_FSH/LH             0.00
# 7        Feature_Fast food (Y/N)             0.00
# 8       Feature_Follicle No. (L)             0.05
# 9       Feature_Follicle No. (R)             0.05
# 10        Feature_Hair loss(Y/N)             0.00
# 11             Feature_Hip(inch)             0.00
# 12            Feature_LH(mIU/mL)             0.00
# 13            Feature_PRG(ng/mL)             0.00
# 14            Feature_PRL(ng/mL)             0.00
# 15          Feature_Pimples(Y/N)             0.00
# 16  Feature_Skin darkening (Y/N)             0.05
# 17           Feature_TSH (mIU/L)             0.00
# 18        Feature_Vit D3 (ng/mL)             0.00
# 19           Feature_Weight (Kg)             0.00
# 20      Feature_Weight gain(Y/N)             0.05
# 21      Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 1 for ensemble_output1_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.04
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_BP _Diastolic (mmHg)             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.00
# 6             Feature_FSH(mIU/mL)             0.00
# 7                  Feature_FSH/LH             0.00
# 8         Feature_Fast food (Y/N)             0.04
# 9        Feature_Follicle No. (L)             0.04
# 10       Feature_Follicle No. (R)             0.04
# 11         Feature_Hair loss(Y/N)             0.00
# 12              Feature_Hip(inch)             0.00
# 13             Feature_LH(mIU/mL)             0.00
# 14  Feature_Marraige Status (Yrs)             0.00
# 15      Feature_No. of aborptions             0.00
# 16             Feature_PRG(ng/mL)             0.00
# 17             Feature_PRL(ng/mL)             0.00
# 18           Feature_Pimples(Y/N)             0.04
# 19      Feature_Reg.Exercise(Y/N)             0.00
# 20   Feature_Skin darkening (Y/N)             0.00
# 21            Feature_TSH (mIU/L)             0.00
# 22         Feature_Vit D3 (ng/mL)             0.00
# 23            Feature_Waist(inch)             0.00
# 24            Feature_Weight (Kg)             0.00
# 25       Feature_Weight gain(Y/N)             0.00
# 26       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 2 for ensemble_output1_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.04
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_BP _Diastolic (mmHg)             0.00
# 4      Feature_Cycle length(days)             0.00
# 5              Feature_Cycle(R/I)             0.04
# 6             Feature_FSH(mIU/mL)             0.00
# 7                  Feature_FSH/LH             0.00
# 8         Feature_Fast food (Y/N)             0.04
# 9        Feature_Follicle No. (L)             0.04
# 10       Feature_Follicle No. (R)             0.00
# 11         Feature_Hair loss(Y/N)             0.00
# 12              Feature_Hip(inch)             0.00
# 13             Feature_LH(mIU/mL)             0.00
# 14  Feature_Marraige Status (Yrs)             0.00
# 15      Feature_No. of aborptions             0.00
# 16             Feature_PRG(ng/mL)             0.00
# 17             Feature_PRL(ng/mL)             0.00
# 18           Feature_Pimples(Y/N)             0.04
# 19      Feature_Reg.Exercise(Y/N)             0.00
# 20   Feature_Skin darkening (Y/N)             0.00
# 21            Feature_TSH (mIU/L)             0.00
# 22         Feature_Vit D3 (ng/mL)             0.00
# 23            Feature_Waist(inch)             0.00
# 24            Feature_Weight (Kg)             0.00
# 25       Feature_Weight gain(Y/N)             0.00
# 26       Feature_hair growth(Y/N)             0.00
#
#
# ...
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.00
# 34       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 3 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.00
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.00
# 13       Feature_Follicle No. (L)             0.03
# 14       Feature_Follicle No. (R)             0.03
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.03
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.03
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.00
# 34       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 4 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.03
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.00
# 13       Feature_Follicle No. (L)             0.03
# 14       Feature_Follicle No. (R)             0.00
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.00
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.03
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.00
# 34       Feature_hair growth(Y/N)             0.03
#
#
# Stability Scores for Fold 5 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.00
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.03
# 13       Feature_Follicle No. (L)             0.00
# 14       Feature_Follicle No. (R)             0.03
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.00
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.00
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.03
# 34       Feature_hair growth(Y/N)             0.03
#
#
# Stability Scores for Fold 6 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.00
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.00
# 13       Feature_Follicle No. (L)             0.03
# 14       Feature_Follicle No. (R)             0.03
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.03
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.03
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.00
# 34       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 7 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.00
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.00
# 13       Feature_Follicle No. (L)             0.03
# 14       Feature_Follicle No. (R)             0.03
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.03
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.03
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.00
# 34       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 8 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.00
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.03
# 13       Feature_Follicle No. (L)             0.03
# 14       Feature_Follicle No. (R)             0.03
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.03
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.00
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.00
# 34       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 9 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.03
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.00
# 13       Feature_Follicle No. (L)             0.03
# 14       Feature_Follicle No. (R)             0.03
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.00
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.00
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.03
# 34       Feature_hair growth(Y/N)             0.00
#
#
# Stability Scores for Fold 10 for ensemble_output2_feature_importances.csv:
#                           Feature  Stability Score
# 0                            Rank             0.03
# 1              Feature_ Age (yrs)             0.00
# 2    Feature_Avg. F size (L) (mm)             0.00
# 3    Feature_Avg. F size (R) (mm)             0.00
# 4                     Feature_BMI             0.00
# 5    Feature_BP _Diastolic (mmHg)             0.00
# 6             Feature_Blood Group             0.00
# 7      Feature_Cycle length(days)             0.00
# 8              Feature_Cycle(R/I)             0.00
# 9        Feature_Endometrium (mm)             0.00
# 10            Feature_FSH(mIU/mL)             0.00
# 11                 Feature_FSH/LH             0.00
# 12        Feature_Fast food (Y/N)             0.03
# 13       Feature_Follicle No. (L)             0.03
# 14       Feature_Follicle No. (R)             0.03
# 15         Feature_Hair loss(Y/N)             0.00
# 16               Feature_Hb(g/dl)             0.00
# 17              Feature_Hip(inch)             0.00
# 18             Feature_LH(mIU/mL)             0.00
# 19  Feature_Marraige Status (Yrs)             0.00
# 20      Feature_No. of aborptions             0.00
# 21             Feature_PRG(ng/mL)             0.00
# 22             Feature_PRL(ng/mL)             0.00
# 23           Feature_Pimples(Y/N)             0.00
# 24          Feature_Pregnant(Y/N)             0.00
# 25             Feature_RBS(mg/dl)             0.00
# 26       Feature_RR (breaths/min)             0.00
# 27      Feature_Reg.Exercise(Y/N)             0.00
# 28   Feature_Skin darkening (Y/N)             0.03
# 29            Feature_TSH (mIU/L)             0.00
# 30         Feature_Vit D3 (ng/mL)             0.00
# 31            Feature_Waist(inch)             0.00
# 32            Feature_Weight (Kg)             0.00
# 33       Feature_Weight gain(Y/N)             0.00
# 34       Feature_hair growth(Y/N)             0.00
#
#
#
# Stability variations for each file:
# chi_square_columns_feature_importances.csv: 0.0319
# mrmr_filtered_output_feature_importances.csv: 0.0468
# pearson_output_pearson_scores_and_ranks.csv: 0.0221
# relief_output_feature_importances.csv: 0.0388
# ensemble_output_feature_importances.csv: 0.0176
# ensemble_output1_feature_importances.csv: 0.0139
# ensemble_output2_feature_importances.csv: 0.0094
#
# The most stable file is: ensemble_output2_feature_importances.csv

# %%
# !pip install pymrmr
# Out:
# Collecting pymrmr
#   Downloading pymrmr-0.1.11.tar.gz (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from pymrmr) (1.26.4)
# Building wheels for collected packages: pymrmr
#   Building wheel for pymrmr (setup.py) ... done
#   Created wheel for pymrmr: filename=pymrmr-0.1.11-cp310-cp310-linux_x86_64.whl size=390762 sha256=93cbdd59a11a925492f778005937c93376e3fbb10bde73517a0b5ae763ea20c7
#   Stored in directory: /root/.cache/pip/wheels/46/ae/55/4a2479c5f0de7eb363fe970cb18e4a750e03e4e63b1b5c2005
# Successfully built pymrmr
# Installing collected packages: pymrmr
# Successfully installed pymrmr-0.1.11

# %%
import pandas as pd
import pymrmr

def mrmr_feature_filter(input_csv, target_column, num_features=10, output_csv='mrmr_filtered_output.csv'):
    # Load the dataset
    df = pd.read_csv(input_csv)

    # Check if the target column exists in the dataset
    if target_column not in df.columns:
        raise ValueError(f"Column '{target_column}' does not exist in the dataset.")

    # Separate the target column from the features
    features = df.drop(columns=[target_column])
    target = df[target_column]

    # Ensure all features are numeric; fill NaNs if needed
    features = features.apply(pd.to_numeric, errors='coerce')
    features.fillna(features.mean(), inplace=True)

    # Combine the target column with features for mRMR input
    df_combined = pd.concat([target, features], axis=1)

    # Perform mRMR feature selection
    try:
        selected_features = pymrmr.mRMR(df_combined, 'MIQ', num_features)
    except Exception as e:
        raise RuntimeError(f"Error during mRMR feature selection: {e}")

    # Ensure the target column is included in the selected features
    if target_column not in selected_features:
        selected_features.insert(0, target_column)

    # Identify irrelevant columns
    irrelevant_columns = [col for col in df.columns if col not in selected_features]

    # Display the results
    print("\n" + "="*50)
    print(f"Total columns in the dataset: {len(df.columns)}")
    print("\nRelevant columns:")
    for col in selected_features:
        print(f"  - {col}")
    print(f"\nNumber of relevant columns: {len(selected_features)}")
    print("\nIrrelevant columns:")
    for col in irrelevant_columns:
        print(f"  - {col}")
    print(f"\nNumber of irrelevant columns: {len(irrelevant_columns)}")
    print("="*50 + "\n")

    # Filter the dataframe to keep only relevant columns
    filtered_df = df[selected_features]

    # Save the filtered dataframe to a new CSV file
    filtered_df.to_csv(output_csv, index=False)
    print(f"Filtered data has been saved to '{output_csv}'")


mrmr_feature_filter('ss.csv', 'PCOS (Y/N)', num_features=22, output_csv='mrmr_features2.csv')
# Out:
# ==================================================
# Total columns in the dataset: 42
#
# Relevant columns:
#   - PCOS (Y/N)
#   -   I   beta-HCG(mIU/mL)
#   - FSH/LH
#   - hair growth(Y/N)
#   - Skin darkening (Y/N)
#   - Weight gain(Y/N)
#   - Cycle(R/I)
#   - Follicle No. (R)
#   - Fast food (Y/N)
#   - Pimples(Y/N)
#   - Follicle No. (L)
#   - Cycle length(days)
#   - II    beta-HCG(mIU/mL)
#   - Hair loss(Y/N)
#   - AMH(ng/mL)
#   - PRG(ng/mL)
#   - Waist(inch)
#   - Vit D3 (ng/mL)
#   - Weight (Kg)
#   - PRL(ng/mL)
#   - Hip(inch)
#   -  Age (yrs)
#   - Avg. F size (L) (mm)
#
# Number of relevant columns: 23
#
# Irrelevant columns:
#   - Height(Cm)
#   - BMI
#   - Blood Group
#   - Pulse rate(bpm)
#   - RR (breaths/min)
#   - Hb(g/dl)
#   - Marraige Status (Yrs)
#   - Pregnant(Y/N)
#   - No. of aborptions
#   - FSH(mIU/mL)
#   - LH(mIU/mL)
#   - Waist:Hip Ratio
#   - TSH (mIU/L)
#   - RBS(mg/dl)
#   - Reg.Exercise(Y/N)
#   - BP _Systolic (mmHg)
#   - BP _Diastolic (mmHg)
#   - Avg. F size (R) (mm)
#   - Endometrium (mm)
#
# Number of irrelevant columns: 19
# ==================================================
#
# Filtered data has been saved to 'mrmr_features2.csv'
